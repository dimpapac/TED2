# %% [markdown]
# <h3>Τεχνικές Εξόρυξης Δεδομένων
# Εαρινό Εξάμηνο 2019-2020
# 2η Άσκηση
# </h3>
# Θεόφιλος-Ιάσονας Κανταρτζής 1115201400061 <br>
# Δημήτρης Παπαχρήστου 1115201500124

# %%
import glob
import pandas as pd
import numpy as np
import os
import io
import csv
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model.logistic import LogisticRegression
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn import svm

from sklearn import preprocessing
from sklearn import metrics
# Out:
# /Users/theophilos/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.linear_model.logistic module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.linear_model. Anything that cannot be imported from sklearn.linear_model is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %% [markdown]
# Δημιουργία ΤSV αρχείων

# %%
# train = 'train_set.tsv'
# counter = 0
# with open(train, 'wt') as out_file:
#     tsv_writer = csv.writer(out_file, delimiter='\t')
#     tsv_writer.writerow(['Id', 'Title','Content','Category'])
#     work_dir = "fulltext/data/business"
#     for path in sorted(glob.glob(os.path.join(work_dir, "*.txt"))):
#         with io.open(path, mode="r", encoding="utf-8") as fd:
#             title = fd.readline()
#             content = ""
#             line = fd.readline()
#             while line:
#                 content += " " + line
#                 line = fd.readline()
#             tsv_writer.writerow([counter, title ,content,"business"])
#             counter += 1
#     work_dir = "fulltext/data/entertainment"
#     for path in sorted(glob.glob(os.path.join(work_dir, "*.txt"))):
#         with io.open(path, mode="r", encoding="utf-8") as fd:
#             title = fd.readline()
#             content = ""
#             line = fd.readline()
#             while line:
#                 content += " " + line
#                 line = fd.readline()
#             tsv_writer.writerow([counter, title ,content,"entertainment"])
#             counter += 1
#     work_dir = "fulltext/data/politics"
#     for path in sorted(glob.glob(os.path.join(work_dir, "*.txt"))):
#         with io.open(path, mode="r", encoding="utf-8") as fd:
#             title = fd.readline()
#             content = ""
#             line = fd.readline()
#             while line:
#                 content += " " + line
#                 line = fd.readline()
#             tsv_writer.writerow([counter, title ,content,"politics"])
#             counter += 1
#     work_dir = "fulltext/data/tech"
#     for path in sorted(glob.glob(os.path.join(work_dir, "*.txt"))):
#         with io.open(path, mode="r", encoding="utf-8") as fd:
#             title = fd.readline()
#             content = ""
#             line = fd.readline()
#             while line:
#                 content += " " + line
#                 line = fd.readline()
#             tsv_writer.writerow([counter, title ,content,"tech"])
#             counter += 1
#     work_dir = "fulltext/data/sport"
#     for path in sorted(glob.glob(os.path.join(work_dir, "*.txt"))):
#         with io.open(path, mode="r") as fd:
#             title = fd.readline()
#             content = ""
#             line = fd.readline()
#             while line:
#                 content += " " + line
#                 line = fd.readline()
#             tsv_writer.writerow([counter, title ,content,"sport"])
#             counter += 1

# %%
trainDf = pd.read_csv("train_set.tsv",sep='\t')
trainDf = trainDf.replace('\n','', regex=True)

# %%
businessDf = trainDf.loc[trainDf['Category'] == 'business'] 
entertainmentDf = trainDf.loc[trainDf['Category'] == 'entertainment'] 
politicsDf = trainDf.loc[trainDf['Category'] == 'politics'] 
sportDf = trainDf.loc[trainDf['Category'] == 'sport'] 
techDf = trainDf.loc[trainDf['Category'] == 'tech']

# %% [markdown]
# <h3>1. Δημιουργία WordCloud</h3>

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
stopwords = set(STOPWORDS)

# %% [markdown]
# <h5>Business WordCloud</h5>

# %%
businessList = businessDf['Content'].tolist()
flatList = []
for b in businessList:
    parsed = b.split()
    for item in parsed:
        flatList.append(item)

        
clean_string = ' '.join(flatList)

wordcloud = WordCloud(width = 800, height = 800,collocations = False,
                background_color ='white', 
                stopwords = stopwords, 
                min_font_size = 10).generate(clean_string) 

plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()

# %% [markdown]
# <h5>Entertainment WordCloud</h5>

# %%
entertainmentList = entertainmentDf['Content'].tolist()
flatList = []
for e in entertainmentList:
    parsed = e.split()
    for item in parsed:
        flatList.append(item)

        
clean_string = ' '.join(flatList)

wordcloud = WordCloud(width = 800, height = 800,collocations = False,
                background_color ='white', 
                stopwords = stopwords, 
                min_font_size = 10).generate(clean_string) 

plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()

# %% [markdown]
# <h5>Politics WordCloud</h5>

# %%
politicsList = politicsDf['Content'].tolist()
flatList = []
for p in politicsList:
    parsed = p.split()
    for item in parsed:
        flatList.append(item)

        
clean_string = ' '.join(flatList)

wordcloud = WordCloud(width = 800, height = 800,collocations = False,
                background_color ='white', 
                stopwords = stopwords, 
                min_font_size = 10).generate(clean_string) 

plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()

# %% [markdown]
# <h5>Sport WordCloud</h5>

# %%
sportList = sportDf['Content'].tolist()
flatList = []
for s in sportList:
    parsed = s.split()
    for item in parsed:
        flatList.append(item)

        
clean_string = ' '.join(flatList)

wordcloud = WordCloud(width = 800, height = 800,collocations = False,
                background_color ='white', 
                stopwords = stopwords, 
                min_font_size = 10).generate(clean_string) 

plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()

# %% [markdown]
# <h5>Tech WordCloud</h5>

# %%
techList = techDf['Content'].tolist()
flatList = []
for t in techList:
    parsed = t.split()
    for item in parsed:
        flatList.append(item)

        
clean_string = ' '.join(flatList)

wordcloud = WordCloud(width = 800, height = 800,collocations = False,
                background_color ='white', 
                stopwords = stopwords, 
                min_font_size = 10).generate(clean_string) 

plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()

# %% [markdown]
# <h3>2.Υλοποίηση Κατηγοριοποίησης (Classification - tf-idf)</h3>

# %%
def print_metrics(category_test,predictions,X_train,category_train):
    print("acurracy")
    print(metrics.accuracy_score(category_test, predictions))
    print()

    # recall
    from sklearn.metrics import precision_recall_fscore_support

    print("recall")
    print("macro")
    print(precision_recall_fscore_support(category_test, predictions, average='macro'))
    print("weighted")
    print(precision_recall_fscore_support(category_test, predictions, average='weighted'))

    print()
    #precision
    print("precision")
    from sklearn.metrics import precision_score
    print("macro")
    print(precision_score(category_test, predictions, average='macro'))
    print("weighted")
    print(precision_score(category_test, predictions, average='weighted'))

    print()
    # F-measure (F1-score)
    print("f1")
    from sklearn.metrics import f1_score
    print("macro")
    print(f1_score(category_test, predictions, average='macro'))
    print("weighted")
    print(f1_score(category_test, predictions, average='weighted'))
    print()
    print("10 FOLD VALIDATION")
    
    f = cross_val_score(classifier, X_train.toarray(),category_train,scoring="f1_weighted", cv=10).mean()
    r = cross_val_score(classifier, X_train.toarray(),category_train,scoring="recall_macro", cv=10).mean()
    p = cross_val_score(classifier, X_train.toarray(),category_train,scoring="precision_weighted", cv=10).mean()
    a = cross_val_score(classifier, X_train.toarray(),category_train,scoring="accuracy", cv=10).mean()
    print("f1-measure")
    print(f)
    print("recall")
    print(r)
    print("precision")
    print(p)
    print("accuracy")
    print(a)

# %%
from sklearn.metrics import classification_report

content_train, content_test, category_train, category_test = train_test_split(trainDf['Content'], trainDf['Category'], test_size=0.2)

#create numeric categories using the LabelEncoder and fit-transorm pipeline
le = preprocessing.LabelEncoder()
le.fit(category_train)
category_train = le.transform(category_train)
category_test = le.transform(category_test)

# %%
vectorizer = TfidfVectorizer(max_df=0.90, min_df=2, max_features=1000, stop_words='english')
contentList = content_train.tolist()
X_train = vectorizer.fit_transform(contentList)
testList = content_test.tolist()
X_test = vectorizer.transform(testList)

# %% [markdown]
# <h4>Support Vector Machines</h4>

# %%
classifier = svm.SVC()
classifier.fit(X_train, category_train)

predictions = classifier.predict(X_test)

# %%
print_metrics(category_test,predictions,X_train,category_train)
# Out:
# acurracy
# 0.9730337078651685
#
# recall
# macro
# (0.9722693357859498, 0.9736842105263159, 0.97267712493942, None)
# weighted
# (0.973565698726232, 0.9730337078651685, 0.9730157562023468, None)
#
# precision
# macro
# 0.9722693357859498
# weighted
# 0.973565698726232
#
# f1
# macro
# 0.97267712493942
# weighted
# 0.9730157562023468
#
# 10 FOLD VALIDATION
# f1-measure
# 0.9685348223257387
# recall
# 0.9675995939216829
# precision
# 0.9694316712910445
# accuracy
# 0.9685393258426966

# %% [markdown]
# <h2>Random Forests</h2>

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
classifier = RandomForestClassifier(max_depth=2, random_state=0)
classifier.fit(X_train, category_train)

predictions = classifier.predict(X_test)

# %%
print_metrics(category_test,predictions,X_train,category_train)
# Out:
# acurracy
# 0.7752808988764045
#
# recall
# macro
# (0.8537061540058115, 0.7550142021720969, 0.7553035331028038, None)
# weighted
# (0.8462605035157752, 0.7752808988764045, 0.7666214131690013, None)
#
# precision
# macro
# 0.8537061540058115
# weighted
# 0.8462605035157752
#
# f1
# macro
# 0.7553035331028038
# weighted
# 0.7666214131690013
#
# 10 FOLD VALIDATION
# f1-measure
# 0.7805930710548259
# recall
# 0.7634882770324352
# precision
# 0.8464673111585835
# accuracy
# 0.7853932584269663

# %% [markdown]
# <h5>Naive Bayes</h5>

# %%
from sklearn.naive_bayes import GaussianNB
from scipy.sparse import *
from scipy import *

# %%
classifier = GaussianNB()
classifier.fit(X_train.todense(), category_train)
predictions = classifier.predict(X_test.todense())

# %%
print_metrics(category_test,predictions,X_train,category_train)
# Out:
# acurracy
# 0.898876404494382
#
# recall
# macro
# (0.8997422662953711, 0.8968822055137844, 0.8971500893877253, None)
# weighted
# (0.9031267358018963, 0.898876404494382, 0.8997660876827025, None)
#
# precision
# macro
# 0.8997422662953711
# weighted
# 0.9031267358018963
#
# f1
# macro
# 0.8971500893877253
# weighted
# 0.8997660876827025
#
# 10 FOLD VALIDATION
# f1-measure
# 0.9046699535479776
# recall
# 0.9040064602981598
# precision
# 0.9105391625610888
# accuracy
# 0.9039325842696628

# %% [markdown]
# <h5>K-Nearest Neighbor</h5>

# %%
from sklearn.metrics.pairwise import euclidean_distances
from collections import Counter
import itertools
# distance between rows of X

def find_category(row,k):
    distances = []
    distances = euclidean_distances(X_train , X_test[row])
    categories = [x for _,x in sorted(zip(distances,category_train))]

    results = categories[:k]
    keys = Counter(results).keys()
    freq = Counter(results).values()
    mostFreq = [x for _,x in sorted(zip(freq,keys))]
    mostFreq = [ele for ele in reversed(mostFreq)] 
    mostFreq = mostFreq[:1]
    return mostFreq


def k_nearest_neighbour(k):
    predictions = []
    for i in range(0,X_test.shape[0]):
        predictions.append(find_category(i,k))
    return predictions


predictions1 = k_nearest_neighbour(1)

# %%
print_metrics(category_test,predictions,X_train,category_train)
# Out:
# acurracy
# 0.898876404494382
#
# recall
# macro
# (0.8997422662953711, 0.8968822055137844, 0.8971500893877253, None)
# weighted
# (0.9031267358018963, 0.898876404494382, 0.8997660876827025, None)
#
# precision
# macro
# 0.8997422662953711
# weighted
# 0.9031267358018963
#
# f1
# macro
# 0.8971500893877253
# weighted
# 0.8997660876827025
#
# 10 FOLD VALIDATION
# f1-measure
# 0.9046699535479776
# recall
# 0.9040064602981598
# precision
# 0.9105391625610888
# accuracy
# 0.9039325842696628

# %% [markdown]
# <h3> 2.Υλοποίηση Κατηγοριοποίησης (Classification - BoW) </h3>

# %%
from sklearn.feature_extraction.text import CountVectorizer
vectorizer = CountVectorizer(max_df=0.90, min_df=2, max_features=1000, stop_words='english')
contentList = content_train.tolist()
X_train = vectorizer.fit_transform(contentList)
testList = content_test.tolist()
X_test = vectorizer.transform(testList)

# %% [markdown]
# <h5>Support Vector Machines</h5>

# %%
classifier = svm.SVC()
classifier.fit(X_train, category_train)

predictions = classifier.predict(X_test)

# %%
print_metrics(category_test,predictions,X_train,category_train)
# Out:
# acurracy
# 0.9415730337078652
#
# recall
# macro
# (0.941025467141024, 0.9418028404344193, 0.9410916579943518, None)
# weighted
# (0.9422305383354427, 0.9415730337078652, 0.9415933898711547, None)
#
# precision
# macro
# 0.941025467141024
# weighted
# 0.9422305383354427
#
# f1
# macro
# 0.9410916579943518
# weighted
# 0.9415933898711547
#
# 10 FOLD VALIDATION
# f1-measure
# 0.9528665364672999
# recall
# 0.9515815796778619
# precision
# 0.9544539817906795
# accuracy
# 0.952808988764045

# %% [markdown]
# <h5>Random Forests</h5>

# %%
classifier = RandomForestClassifier(max_depth=2, random_state=0)
classifier.fit(X_train, category_train)

predictions = classifier.predict(X_test)

# %%
print_metrics(category_test,predictions,X_train,category_train)
# Out:
# acurracy
# 0.7752808988764045
#
# recall
# macro
# (0.8510538926979747, 0.754157059314954, 0.7522923250506941, None)
# weighted
# (0.8423785587286894, 0.7752808988764045, 0.7635510115109243, None)
#
# precision
# macro
# 0.8510538926979747
# weighted
# 0.8423785587286894
#
# f1
# macro
# 0.7522923250506941
# weighted
# 0.7635510115109243
#
# 10 FOLD VALIDATION
# f1-measure
# 0.7942039962416968
# recall
# 0.7779725115888569
# precision
# 0.8570785177085097
# accuracy
# 0.7988764044943821

# %% [markdown]
# <h5>Naive Bayes</h5>

# %%
classifier = GaussianNB()
classifier.fit(X_train.todense(), category_train)
predictions = classifier.predict(X_test.todense())

# %%
print_metrics(category_test,predictions,X_train,category_train)
# Out:
# acurracy
# 0.903370786516854
#
# recall
# macro
# (0.905677830940989, 0.9002472848788639, 0.9018987431806904, None)
# weighted
# (0.9066481320768723, 0.903370786516854, 0.9039289915703526, None)
#
# precision
# macro
# 0.905677830940989
# weighted
# 0.9066481320768723
#
# f1
# macro
# 0.9018987431806904
# weighted
# 0.9039289915703526
#
# 10 FOLD VALIDATION
# f1-measure
# 0.9118652198874095
# recall
# 0.9120857869183006
# precision
# 0.9168155920806379
# accuracy
# 0.9112359550561797

# %% [markdown]
# <h5>K-Nearest Neighbor<h5>

# %%
def find_category(row,k):
    distances = []
    distances = euclidean_distances(X_train , X_test[row])
    categories = [x for _,x in sorted(zip(distances,category_train))]

    results = categories[:k]
    keys = Counter(results).keys()
    freq = Counter(results).values()
    mostFreq = [x for _,x in sorted(zip(freq,keys))]
    mostFreq = [ele for ele in reversed(mostFreq)] 
    mostFreq = mostFreq[:1]
    return mostFreq


def k_nearest_neighbour(k):
    predictions = []
    for i in range(0,X_test.shape[0]):
        predictions.append(find_category(i,k))
    return predictions


predictions1 = k_nearest_neighbour(1)

# %%
# predictions = list(itertools.chain(*predictions1))
print_metrics(category_test,predictions,X_train,category_train)
# Out:
# acurracy
# 0.903370786516854
#
# recall
# macro
# (0.905677830940989, 0.9002472848788639, 0.9018987431806904, None)
# weighted
# (0.9066481320768723, 0.903370786516854, 0.9039289915703526, None)
#
# precision
# macro
# 0.905677830940989
# weighted
# 0.9066481320768723
#
# f1
# macro
# 0.9018987431806904
# weighted
# 0.9039289915703526
#
# 10 FOLD VALIDATION
# f1-measure
# 0.9118652198874095
# recall
# 0.9120857869183006
# precision
# 0.9168155920806379
# accuracy
# 0.9112359550561797

# %% [markdown]
# <h3>4. Υλοποίηση Συσταδοποίησης (Clustering)</h3>

# %% [markdown]
# <h5>K_MEANS WITH COSINE SIMILARITY (TFID VECTORIZER)</h5>

# %%
from sklearn.metrics.pairwise import cosine_similarity

features = 10

vectorizer = TfidfVectorizer(max_df=0.90, min_df=10, max_features=features, stop_words='english')
contentList = content_train.tolist()
X_train = vectorizer.fit_transform(contentList)


data = pd.DataFrame.sparse.from_spmatrix(X_train)

# %%
#Select 5 random centroids from the dataset
centroids = list()
for i in range(5):
    x = random.randint(0,X_train.shape[0]) 
    centroids.append(X_train[x])

# %%
def calculate_distance(centroid):
    distances = cosine_similarity(X_train,centroid).tolist()
    flattened = [val for sublist in distances for val in sublist]
    return flattened

# %%
data['C1_Distance'] = calculate_distance(centroids[0])
data['C2_Distance'] = calculate_distance(centroids[1])
data['C3_Distance'] = calculate_distance(centroids[2])
data['C4_Distance'] = calculate_distance(centroids[3])
data['C5_Distance'] = calculate_distance(centroids[4])

# Get the minimum distance centroids
data['Cluster'] = data[['C1_Distance', 'C2_Distance', 'C3_Distance','C4_Distance','C5_Distance']].apply(np.argmax, axis =1) + 1


means = []
for i in range(1,6):
    means.clear()
    check = len(data[data['Cluster'] == i ])
    if check != 0 :
        for j in range(features):
            means.append(data[data['Cluster']== i ][j].mean())
        centroids[i-1] = csr_matrix( means , shape=(1,features) )
means.clear()


result = data.iloc[:,15:].values
result1 = result.tolist()
result2 = []
counter = 0

while result1 != result2 :
    
    if counter > 0:
        result1 = result2
    
    data['C1_Distance'] = calculate_distance(centroids[0])
    data['C2_Distance'] = calculate_distance(centroids[1])
    data['C3_Distance'] = calculate_distance(centroids[2])
    data['C4_Distance'] = calculate_distance(centroids[3])
    data['C5_Distance'] = calculate_distance(centroids[4])
    
    data['Cluster'] = data[['C1_Distance', 'C2_Distance', 'C3_Distance','C4_Distance','C5_Distance']].apply(np.argmax, axis =1) + 1
    
    means = []
    for i in range(1,6):
        means.clear()
        check = len(data[data['Cluster'] == i ])
        if check != 0 :
            for j in range(features):
                means.append(data[data['Cluster']== i ][j].mean())
            centroids[i-1] = csr_matrix( means , shape=(1,features) )
    means.clear()
    result = data.iloc[:,15:].values
    result2 = result.tolist()
    counter += 1

# %%
flattened = [val for sublist in result2 for val in sublist]
result = np.asarray(flattened)

# %%
import matplotlib.pyplot as plt

from sklearn import datasets
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis


X = X_train.toarray()
y = result
target_names = ['1','2','3','4','5']
pca = PCA(n_components=10)
X_r = pca.fit(X).transform(X)
lda = LinearDiscriminantAnalysis(n_components=2)
X_r2 = lda.fit(X, y).transform(X)
# Percentage of variance explained for each components
print('explained variance ratio (first two components): %s'
      % str(pca.explained_variance_ratio_))
plt.figure()
colors = ['navy', 'turquoise', 'darkorange' , 'green' , 'red']
lw = 0.5

for color, i, target_name in zip(colors, [1, 2, 3 , 4 , 5], target_names):
    plt.scatter(X_r[y == i, 0], X_r[y == i, 1], color=color, alpha=.8, lw=lw,
                label=target_name)
plt.legend(loc='best', shadow=False, scatterpoints=1)
plt.title('PCA')
plt.rcParams["figure.figsize"] = (9,9)

plt.show()
# Out:
# explained variance ratio (first two components): [0.18470041 0.1577044  0.11664855 0.10598377 0.10020482 0.08909791
#  0.08092598 0.07304955 0.06553552 0.02614908]

# %% [markdown]
# <h5>K_MEANS WITH COSINE SIMILARITY (BOW VECTORIZER)</h5>

# %%
from sklearn.metrics.pairwise import cosine_similarity

features = 10

vectorizer = CountVectorizer(max_df=0.90, min_df=2, max_features=features, stop_words='english')
contentList = content_train.tolist()
X_train = vectorizer.fit_transform(contentList)


data = pd.DataFrame.sparse.from_spmatrix(X_train)

# %%
#Select 5 random centroids from the dataset
centroids = list()
for i in range(5):
    x = random.randint(0,X_train.shape[0]) 
    centroids.append(X_train[x])

# %%
def calculate_distance(centroid):
    distances = cosine_similarity(X_train,centroid).tolist()
    flattened = [val for sublist in distances for val in sublist]
    return flattened

# %%
data['C1_Distance'] = calculate_distance(centroids[0])
data['C2_Distance'] = calculate_distance(centroids[1])
data['C3_Distance'] = calculate_distance(centroids[2])
data['C4_Distance'] = calculate_distance(centroids[3])
data['C5_Distance'] = calculate_distance(centroids[4])

# Get the minimum distance centroids
data['Cluster'] = data[['C1_Distance', 'C2_Distance', 'C3_Distance','C4_Distance','C5_Distance']].apply(np.argmax, axis =1) + 1


means = []
for i in range(1,6):
    means.clear()
    check = len(data[data['Cluster'] == i ])
    if check != 0 :
        for j in range(features):
            means.append(data[data['Cluster']== i ][j].mean())
        centroids[i-1] = csr_matrix( means , shape=(1,features) )
means.clear()


result = data.iloc[:,15:].values
result1 = result.tolist()
result2 = []
counter = 0

while result1 != result2 :
    
    if counter > 0:
        result1 = result2
    
    data['C1_Distance'] = calculate_distance(centroids[0])
    data['C2_Distance'] = calculate_distance(centroids[1])
    data['C3_Distance'] = calculate_distance(centroids[2])
    data['C4_Distance'] = calculate_distance(centroids[3])
    data['C5_Distance'] = calculate_distance(centroids[4])
    
    data['Cluster'] = data[['C1_Distance', 'C2_Distance', 'C3_Distance','C4_Distance','C5_Distance']].apply(np.argmax, axis =1) + 1
    
    means = []
    for i in range(1,6):
        means.clear()
        check = len(data[data['Cluster'] == i ])
        if check != 0 :
            for j in range(features):
                means.append(data[data['Cluster']== i ][j].mean())
            centroids[i-1] = csr_matrix( means , shape=(1,features) )
    means.clear()
    result = data.iloc[:,15:].values
    result2 = result.tolist()
    counter += 1

# %%
flattened = [val for sublist in result2 for val in sublist]
result = np.asarray(flattened)

# %%
import matplotlib.pyplot as plt

from sklearn import datasets
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis


X = X_train.toarray()
y = result
target_names = ['1','2','3','4','5']
pca = PCA(n_components=10)
X_r = pca.fit(X).transform(X)
lda = LinearDiscriminantAnalysis(n_components=2)
X_r2 = lda.fit(X, y).transform(X)
# Percentage of variance explained for each components
print('explained variance ratio (first two components): %s'
      % str(pca.explained_variance_ratio_))
plt.figure()
colors = ['navy', 'turquoise', 'darkorange' , 'green' , 'red']
lw = 0.5

for color, i, target_name in zip(colors, [1, 2, 3 , 4 , 5], target_names):
    plt.scatter(X_r[y == i, 0], X_r[y == i, 1], color=color, alpha=.8, lw=lw,
                label=target_name)
plt.legend(loc='best', shadow=False, scatterpoints=1)
plt.title('PCA')
plt.rcParams["figure.figsize"] = (9,9)

plt.show()
# Out:
# explained variance ratio (first two components): [0.37738003 0.17307491 0.12302283 0.06604591 0.05815812 0.05328876
#  0.04472422 0.04017293 0.03487677 0.02925553]
